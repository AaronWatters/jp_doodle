# %% [markdown]
# # Features demos index
#
# This collection of notebooks illustrates features provided by the `jp_doodle` canvas.
#
# <table>
#     <tr>
#         <td>
#             <img src="Circles.png" width="200px"/>
#         </td>
#         <td>
#             <a href="Circles.ipynb">
#                 Drawing circles on dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Polygons.png" width="200px"/>
#         </td>
#         <td>
#             <a href="Polygons and polylines.ipynb">
#                 Drawing polygons and polylines on dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Rectangles.png" width="200px"/>
#         </td>
#         <td>
#             <a href="Rectangles.ipynb">
#                 Drawing rectangles on dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Images.png" width="200px"/>
#         </td>
#         <td>
#             <a href="Images.ipynb">
#                 Drawing images on dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Text.png" width="200px"/>
#         </td>
#         <td>
#             <a href="Text.ipynb">
#                 Drawing text on dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Events.png" width="200px"/>
#         </td>
#         <td>
#             <a href="Events.ipynb">
#                 Event handling in dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Snapshot.png" width="200px"/>
#         </td>
#         <td>
#             <a href="Snapshot.ipynb">
#                 Snapshotting dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Fit.png" width="200px"/>
#         </td>
#         <td>
#             <a href="The fit method.ipynb">
#                 Fitting dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Changing.png" width="200px"/>
#         </td>
#         <td>
#             <a href="Changing elements.ipynb">
#                 Changing elements on dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Forgetting.png" width="200px"/>
#         </td>
#         <td>
#             <a href="Forgetting, hiding, and resetting.ipynb">
#                 Forgetting, hiding, and resetting in dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Transitions.png" width="200px"/>
#         </td>
#         <td>
#             <a href="Transitions.ipynb">
#                 Interpolated transitions in dual canvases
#             </a>
#         </td>
#     </tr>
# </table>
