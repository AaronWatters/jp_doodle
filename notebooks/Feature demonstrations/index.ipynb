# %% [markdown]
# # Features demos index
#
# This collection of notebooks illustrates features provided by the `jp_doodle` dual canvas.
#
# <table>
#     <tr>
#         <td>
#             <img src="Circles.png" width="200px"/>
#         </td>
#         <td>
#             <h2>Circles</h2>
#             <a href="Circles.ipynb">
#                 Drawing circles on dual canvases.
#             </a>
#         </td>
#         <td>
#                 <img src="interactive_circle.png" width="200px"/><br>
#                 <a href="Interactive circle parameters.ipynb">Interactive circle parameters</a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Polygons.png" width="200px"/>
#         </td>
#         <td>
#             <h2>Polygons</h2>
#             <a href="Polygons and polylines.ipynb">
#                 Drawing polygons and polylines on dual canvases.
#             </a>
#         </td>
#         <td>
#                 <img src="interactive_polygon.png" width="200px"/><br>
#                 <a href="Interactive polygon.ipynb">Interactive polygon parameters</a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Lines.png" width="200px"/>
#         </td>
#         <td>
#             <h2>Lines</h2>
#             <a href="Lines.ipynb">
#                 Drawing lines (line segments) on dual canvases.
#             </a>
#         </td>
#         <td>
#                 <img src="interactive_line.png" width="200px"/><br>
#                 <a href="Interactive lines.ipynb">Interactive line parameters</a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Rectangles.png" width="200px"/>
#         </td>
#         <td>
#             <h2>Rectangles</h2>
#             <a href="Rectangles.ipynb">
#                 Drawing rectangles on dual canvases.
#             </a>
#         </td>
#         <td>
#                 <img src="interactive_rectangle.png" width="200px"/><br>
#                 <a href="Interactive rect.ipynb">Interactive rectangle parameters</a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Images.png" width="200px"/>
#         </td>
#         <td>
#             <h2>Images</h2>
#             <a href="Images.ipynb">
#                 Drawing images on dual canvases.
#             </a>
#         </td>
#         <td>
#                 <img src="interactive_image.png" width="200px"/><br>
#                 <a href="Interactive image.ipynb">Interactive image parameters</a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Text.png" width="200px"/>
#         </td>
#         <td>
#             <h2>Text</h2>
#             <a href="Text.ipynb">
#                 Drawing text on dual canvases.
#             </a>
#         </td>
#         <td>
#                 <img src="interactive_text.png" width="200px"/><br>
#                 <a href="Interactive text.ipynb">Interactive text parameters</a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Frame.png" width="200px"/>
#         </td>
#         <td>
#             <h2>Frames</h2>
#             <a href="Frames.ipynb">
#                 Reference frames manage groups of objects with a shared geometric transform.
#             </a>
#         </td>
#         <td>
#                 <img src="interactive_frame.png" width="200px"/><br>
#                 <a href="Interactive frame.ipynb">Interactive frame parameters</a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Axes.png" width="200px"/>
#         </td>
#         <td>
#             <h2>Axes</h2>
#             <a href="Axes.ipynb">
#                 Axis helpers in dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Events.png" width="200px"/>
#         </td>
#         <td>
#             <h2>Events</h2>
#             <a href="Events.ipynb">
#                 Event handling in dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Snapshot.png" width="200px"/>
#         </td>
#         <td>
#             <h2>Snapshots</h2>
#             <a href="Snapshot.ipynb">
#                 Snapshotting dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Fit.png" width="200px"/>
#         </td>
#         <td>
#             <h2>Fitting</h2>
#             <a href="The fit method.ipynb">
#                 Fitting dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Changing.png" width="200px"/>
#         </td>
#         <td>
#             <h2>Changes</h2>
#             <a href="Changing elements.ipynb">
#                 Changing elements on dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Forgetting.png" width="200px"/>
#         </td>
#         <td>
#             <h2>Forgetting</h2>
#             <a href="Forgetting, hiding, and resetting.ipynb">
#                 Forgetting, hiding, and resetting in dual canvases.
#             </a>
#         </td>
#     </tr>
#     <tr>
#         <td>
#             <img src="Transitions.png" width="200px"/>
#         </td>
#         <td>
#             <h2>Transitions</h2>
#             <a href="Transitions.ipynb">
#                 Interpolated transitions in dual canvases
#             </a>
#         </td>
#     </tr>
# </table>
